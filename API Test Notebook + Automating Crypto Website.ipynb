# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '80551e90-4174-4bdc-a4ff-8e40728bdad0',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2023-03-07T16:08:04.365Z', 'error_code': 0, 'error_message': None, 'elapsed': 19, 'credit_count': 1, 'notice': None, 'total_count': 9039}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10081, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.Timestamp('now')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22084\982800540.py in <module>
# ----> 1 df = pd.json_normalize(data['data'])
#       2 df['timestamp'] = pd.Timestamp('now')
#       3 df
#
# NameError: name 'data' is not defined

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

# %%
def api_runner():
    global df
    
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '80551e90-4174-4bdc-a4ff-8e40728bdad0',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    df2 = pd.json_normalize(data['data'])
    df2['timestamp'] = pd.Timestamp('now')
    df_append = pd.DataFrame(df2)
    df = pd.concat([df2,df_append])

    #if not os.path.isfile(r'C:\Users\joaop\Desktop\Pyhton/API.csv'):
        #df.to_csv(r'C:\Users\joaop\Desktop\Pyhton/API.csv', header='column_names')
    #else:
        #df.to_csv(r'C:\Users\joaop\Desktop\Pyhton/API.csv', mode='a', header=False)

# %%
import os
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed!')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# API Runner completed!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27296\4288629852.py in <module>
#       6     api_runner()
#       7     print('API Runner completed!')
# ----> 8     sleep(60) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
#df70 = pd.read_csv(r'C:\Users\joaop\Desktop\Pyhton/API.csv')
#df70
# Out:
#     Unnamed: 0    id         name symbol          slug  num_market_pairs  \
# 0            0     1      Bitcoin    BTC       bitcoin             10081
# 1            1  1027     Ethereum    ETH      ethereum              6556
# 2            2   825       Tether   USDT        tether             48885
# 3            3  1839          BNB    BNB           bnb              1207
# 4            4  3408     USD Coin   USDC      usd-coin             10473
# 5            5    52          XRP    XRP           xrp               900
# 6            6  2010      Cardano    ADA       cardano               671
# 7            7  3890      Polygon  MATIC       polygon               602
# 8            8    74     Dogecoin   DOGE      dogecoin               653
# 9            9  4687  Binance USD   BUSD   binance-usd              6349
# 10          10  5426       Solana    SOL        solana               439
# 11          11  6636     Polkadot    DOT  polkadot-new               477
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df3= df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          0.07946                      -1.08919
# Ethereum                        -0.26446                      -1.30250
# Tether                          -0.00153                      -0.00602
# BNB                             -0.11747                      -0.48320
# USD Coin                        -0.02193                      -0.02015
# XRP                             -0.77254                       2.90606
# Cardano                          0.09568                      -2.43373
# Polygon                         -0.14236                      -0.82613
# Dogecoin                        -0.15925                      -1.37746
# Binance USD                     -0.00354                      -0.00154
# Solana                          -0.72117                      -3.67660
# Polkadot                         0.07620                      -2.75611
# ...

# %%
df4 =df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h      0.07946
#              quote.USD.percent_change_24h    -1.08919
#              quote.USD.percent_change_7d     -5.33121
#              quote.USD.percent_change_30d    -3.83368
#              quote.USD.percent_change_60d    32.46343
#              quote.USD.percent_change_90d    32.46523
# Ethereum     quote.USD.percent_change_1h     -0.26446
#              quote.USD.percent_change_24h    -1.30250
#              quote.USD.percent_change_7d     -5.32905
#              quote.USD.percent_change_30d    -5.60112
#              quote.USD.percent_change_60d    23.37096
#              quote.USD.percent_change_90d    26.29093
# Tether       quote.USD.percent_change_1h     -0.00153
#              quote.USD.percent_change_24h    -0.00602
#              quote.USD.percent_change_7d     -0.01428
#              quote.USD.percent_change_30d    -0.01901
#              quote.USD.percent_change_60d     0.03394
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h    0.07946
#             quote.USD.percent_change_24h  -1.08919
#             quote.USD.percent_change_7d   -5.33121
#             quote.USD.percent_change_30d  -3.83368
#             quote.USD.percent_change_60d  32.46343
#             quote.USD.percent_change_90d  32.46523
# Ethereum    quote.USD.percent_change_1h   -0.26446
#             quote.USD.percent_change_24h  -1.30250
#             quote.USD.percent_change_7d   -5.32905
#             quote.USD.percent_change_30d  -5.60112
#             quote.USD.percent_change_60d  23.37096
#             quote.USD.percent_change_90d  26.29093
# Tether      quote.USD.percent_change_1h   -0.00153
#             quote.USD.percent_change_24h  -0.00602
#             quote.USD.percent_change_7d   -0.01428
#             quote.USD.percent_change_30d  -0.01901
#             quote.USD.percent_change_60d   0.03394
# ...

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))

df6 = df5.reset_index()
df6
# Out:
#            name                       level_1    values
# 0       Bitcoin   quote.USD.percent_change_1h   0.07946
# 1       Bitcoin  quote.USD.percent_change_24h  -1.08919
# 2       Bitcoin   quote.USD.percent_change_7d  -5.33121
# 3       Bitcoin  quote.USD.percent_change_30d  -3.83368
# 4       Bitcoin  quote.USD.percent_change_60d  32.46343
# 5       Bitcoin  quote.USD.percent_change_90d  32.46523
# 6      Ethereum   quote.USD.percent_change_1h  -0.26446
# 7      Ethereum  quote.USD.percent_change_24h  -1.30250
# 8      Ethereum   quote.USD.percent_change_7d  -5.32905
# 9      Ethereum  quote.USD.percent_change_30d  -5.60112
# 10     Ethereum  quote.USD.percent_change_60d  23.37096
# 11     Ethereum  quote.USD.percent_change_90d  26.29093
# 12       Tether   quote.USD.percent_change_1h  -0.00153
# 13       Tether  quote.USD.percent_change_24h  -0.00602
# 14       Tether   quote.USD.percent_change_7d  -0.01428
# 15       Tether  quote.USD.percent_change_30d  -0.01901
# ...

# %%
df7 = df6.rename(columns={'level_1':'percent_change'})
df7
# Out:
#            name                percent_change    values
# 0       Bitcoin   quote.USD.percent_change_1h   0.07946
# 1       Bitcoin  quote.USD.percent_change_24h  -1.08919
# 2       Bitcoin   quote.USD.percent_change_7d  -5.33121
# 3       Bitcoin  quote.USD.percent_change_30d  -3.83368
# 4       Bitcoin  quote.USD.percent_change_60d  32.46343
# 5       Bitcoin  quote.USD.percent_change_90d  32.46523
# 6      Ethereum   quote.USD.percent_change_1h  -0.26446
# 7      Ethereum  quote.USD.percent_change_24h  -1.30250
# 8      Ethereum   quote.USD.percent_change_7d  -5.32905
# 9      Ethereum  quote.USD.percent_change_30d  -5.60112
# 10     Ethereum  quote.USD.percent_change_60d  23.37096
# 11     Ethereum  quote.USD.percent_change_90d  26.29093
# 12       Tether   quote.USD.percent_change_1h  -0.00153
# 13       Tether  quote.USD.percent_change_24h  -0.00602
# 14       Tether   quote.USD.percent_change_7d  -0.01428
# 15       Tether  quote.USD.percent_change_30d  -0.01901
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#            name percent_change    values
# 0       Bitcoin             1h   0.07946
# 1       Bitcoin            24h  -1.08919
# 2       Bitcoin             7d  -5.33121
# 3       Bitcoin            30d  -3.83368
# 4       Bitcoin            60d  32.46343
# 5       Bitcoin            90d  32.46523
# 6      Ethereum             1h  -0.26446
# 7      Ethereum            24h  -1.30250
# 8      Ethereum             7d  -5.32905
# 9      Ethereum            30d  -5.60112
# 10     Ethereum            60d  23.37096
# 11     Ethereum            90d  26.29093
# 12       Tether             1h  -0.00153
# 13       Tether            24h  -0.00602
# 14       Tether             7d  -0.01428
# 15       Tether            30d  -0.01901
# 16       Tether            60d   0.03394
# 17       Tether            90d  -0.00753
# 18          BNB             1h  -0.11747
# 19          BNB            24h  -0.48320
# 20          BNB             7d  -5.89687
# 21          BNB            30d -12.66059
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin      22261.58779 2023-03-07 16:32:37.666427
# 0  Bitcoin      22261.58779 2023-03-07 16:32:37.666427

# %%
sns.set_theme(style="darkgrid")
sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='quote.USD.price'>

# %%
df10 = df.reset_index()
